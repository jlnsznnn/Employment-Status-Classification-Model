# %% [markdown]
# # Section 6: Training and testing

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt


df = pd.read_csv("cleaned_data_v2.csv") 

display(df)
# Out:
#       PUFC04_SEX  PUFC05_AGE             PUFC06_MSTAT  \
# 0           Male          49  Married/Living Together
# 1         Female          61  Married/Living Together
# 2           Male          19                   Single
# 3           Male          48  Married/Living Together
# 4         Female          41  Married/Living Together
# ...          ...         ...                      ...
# 92236       Male          34  Married/Living Together
# 92237     Female          32  Married/Living Together
# 92238       Male          29  Married/Living Together
# 92239     Female          29  Married/Living Together
# 92240       Male          18                   Single
#
#                     PUFC07_GRADE PUFC09_GRADTECH PUFC11_WORK  \
# 0           High School Graduate              No         Yes
# 1           High School Graduate              No         Yes
# 2           High School Graduate              No         Yes
# 3      High School - Second Year              No         Yes
# 4           High School Graduate              No         Yes
# ...                          ...             ...         ...
# 92236         No grade completed              No         Yes
# 92237         No grade completed              No         Yes
# 92238       High School Graduate              No         Yes
# 92239       College - Third Year              No          No
# 92240       High School Graduate              No         Yes
#
#                                             PUFC14_PROCC   PUFC17_NATEM  \
# 0           Market-oriented skilled agricultural workers  Permanent Job
# 1            Agricultural, forestry and fishery laborers     Short-term
# 2            Agricultural, forestry and fishery laborers     Short-term
# 3           Market-oriented skilled agricultural workers  Permanent Job
# 4                                   Cleaners and helpers  Permanent Job
# ...                                                  ...            ...
# 92236  Market-oriented skilled forestry, fishery and ...  Permanent Job
# 92237       Market-oriented skilled agricultural workers  Permanent Job
# 92238       Production and specialized services managers  Permanent Job
# 92239                                            Unknown        Unknown
# 92240       Production and specialized services managers  Permanent Job
#
#        PUFC18_PNWHRS  PUFC19_PHOURS                        PUFC23_PCLASS  \
# 0                  8             24                        Self Employed
# 1                  4              8  Without Pay (Family owned Business)
# 2                  8             24                Private Establishment
# 3                  4             20                        Self Employed
# 4                 12             72                    Private Household
# ...              ...            ...                                  ...
# 92236              5             30                        Self Employed
# 92237              4             28                        Self Employed
# 92238              8             40                             Employer
# 92239              0              0                              Unknown
# 92240              4             28                        Self Employed
#
#       PUFC41_WQTR           PUFNEWEMPSTAT
# 0             Yes                Employed
# 1             Yes                Employed
# 2             Yes                Employed
# 3             Yes                Employed
# 4             Yes                Employed
# ...           ...                     ...
# 92236         Yes                Employed
# 92237         Yes                Employed
# 92238         Yes                Employed
# 92239     Unknown  Not in the Labor Force
# 92240         Yes                Employed
#
# [92241 rows x 13 columns]

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder


categorical_cols = df.select_dtypes(include=['object']).columns ## filter to object cols

label_encoders = {}

## this encode the columns
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  

## print the mappings 
for col, le in label_encoders.items():
    mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    print()
    print(col)
    for original, encoded in mapping.items():
        print(f"{original} -> {encoded}")
# Out:
# PUFC04_SEX
# Female -> 0
# Male -> 1
#
# PUFC06_MSTAT
# Annulled -> 0
# Divorced/Separated -> 1
# Married/Living Together -> 2
# Single -> 3
# Unknown -> 4
# Widowed -> 5
#
# PUFC07_GRADE
# College - First Year -> 0
# College - Fourth Year -> 1
# College - Second Year -> 2
# College - Third Year -> 3
# Elementary Graduate -> 4
# Grade 1 -> 5
# Grade 2 -> 6
# Grade 3 -> 7
# Grade 4 -> 8
# Grade 5 -> 9
# Grade 6 -> 10
# High School - First Year -> 11
# High School - Second Year -> 12
# High School - Third Year -> 13
# High School Graduate -> 14
# No grade completed -> 15
# Post Baccalaureate -> 16
# Post Secondary - First Year -> 17
# Post Secondary - Second Year -> 18
# Preschool -> 19
# Unknown -> 20
#
# PUFC09_GRADTECH
# No -> 0
# Yes -> 1
#
# PUFC11_WORK
# No -> 0
# Yes -> 1
#
# PUFC14_PROCC
# Administrative and commercial managers -> 0
# Agricultural, forestry and fishery laborers -> 1
# Armed forces occupations, other ranks -> 2
# Assemblers -> 3
# Building and related trades workers, excluding electricians -> 4
# Business and administration associate professionals -> 5
# Business and administration professionals -> 6
# Chief executives, senior officials and legislators -> 7
# Cleaners and helpers -> 8
# Commissioned armed forces officers -> 9
# Customer service clerks -> 10
# Drivers and mobile plant operators -> 11
# Electrical and electronics trades workers -> 12
# Food preparation assistants -> 13
# Food processing, wood working, garment and other craft and related trades workers -> 14
# General and keyboard clerks -> 15
# Handicraft and printing workers -> 16
# Health associate professionals -> 17
# Health professionals -> 18
# Hospitality, retail and other services managers -> 19
# Information and communication technology professionals -> 20
# Information and communications technician -> 21
# Laborers in mining, construction, manufacturing and transport -> 22
# Legal, social and cultural professionals -> 23
# Legal, social, cultural and related professionals -> 24
# Market-oriented skilled agricultural workers -> 25
# Market-oriented skilled forestry, fishery and hunting workers -> 26
# Metal, machinery and related trades workers -> 27
# Non-commissioned armed forces officers -> 28
# Numerical and material recording clerks -> 29
# Other clerical support workers -> 30
# Personal care workers -> 31
# Personal service workers -> 32
# Production and specialized services managers -> 33
# Protective services workers -> 34
# Refuse workers and other elementary workers -> 35
# Sales workers -> 36
# Science and engineering associate professionals -> 37
# Science and engineering professionals -> 38
# Stationary plant and machine operators -> 39
# Street and related sales and service workers -> 40
# Subsistence farmers, fishers, hunters and gatherers -> 41
# Teaching professionals -> 42
# Unknown -> 43
#
# PUFC17_NATEM
# Different Employer -> 0
# Permanent Job -> 1
# Short-term -> 2
# Unknown -> 3
#
# PUFC23_PCLASS
# Employer -> 0
# Govt/Govt Corporation -> 1
# Private Establishment -> 2
# Private Household -> 3
# Self Employed -> 4
# Unknown -> 5
# With Pay (Family Owned Business) -> 6
# Without Pay (Family owned Business) -> 7
#
# PUFC41_WQTR
# No -> 0
# Unknown -> 1
# Yes -> 2
#
# PUFNEWEMPSTAT
# Employed -> 0
# Not in the Labor Force -> 1
# Unemployed -> 2

# %% [markdown]
# Assign Target Value and Features

# %%
X = df.drop(columns=["PUFNEWEMPSTAT"]).values
y = df["PUFNEWEMPSTAT"].values

# %% [markdown]
# Normalizing Data: Standerdizes the features to have a mean of 0 and a standard deviation of 1, which helps the neural network converge faster

# %%
X = (X - X.mean(axis=0)) / X.std(axis=0)

# %% [markdown]
# Train-Test Split: Split data into 70% training and 30% testing
# - Stratify ensures the proportion of classes remains balanced between training and testing sets
# - Random State ensures reproducibility

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.title('Train data')
# Out:
# Text(0.5, 1.0, 'Train data')

# %%
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test)
plt.title('Test data')
# Out:
# Text(0.5, 1.0, 'Test data')

# %% [markdown]
# Convert to PyTorch Tensors for PyTorch processing
# - torch.float32 is sued for features, and torch.long is used for classification labels

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
print(X_train.shape)

y_train = torch.tensor(y_train, dtype=torch.long)
print(y_train.shape)

X_test = torch.tensor(X_test, dtype=torch.float32)
print(X_test.shape)

y_test = torch.tensor(y_test, dtype=torch.long)
print(y_test.shape)
# Out:
# torch.Size([64568, 12])
# torch.Size([64568])
# torch.Size([27673, 12])
# torch.Size([27673])

# %% [markdown]
# Data Loader Class
# - DataLoader: Efficiently manages batches for training
# - Shuffling : Ensures each epoch has a randomized set of samples to prevent the model from learning the order of data
# - Batching : Data is divided into smaller, managable chunks using the specified batch size

# %%
import numpy as np

class DataLoader(object):

    def __init__(self, X, y, batch_size):
      
        self.X = X
        self.y = y
        self.batch_size = batch_size

        self.indices = np.array([i for i in range(self.X.shape[0])])
        np.random.seed(1)

    def shuffle(self):
       
        np.random.shuffle(self.indices)

    def get_batch(self, mode='train'):


        X_batch = []
        y_batch = []

    
        if mode == 'train':
            self.shuffle()
        elif mode == 'test':
            self.indices = np.array([i for i in range(self.X.shape[0])])

       
        for i in range(0, len(self.indices), self.batch_size):

           
            if i + self.batch_size <= len(self.indices):
                indices = self.indices[i:i + self.batch_size]

        
            else:
                indices = self.indices[i:]

            X_batch.append(self.X[indices])
            y_batch.append(self.y[indices])

        return X_batch, y_batch

# %% [markdown]
# Neural Network Class
# - Input Size: Number of Features (12)
# - Number of Classes : Employed, Unemployed, Not in the LAbor Force, Unknown
# - Hidden Layers : Customizable with size [64, 32]
#
#
# Building Layers
# - Linear Layers: Each layer has weights and biases
# - ReLU Activation: Common in deep learning, applying non-linearity to capture complex patterns
#
#
# Forward Pass
# - Network Pass: Passes input through all layers
# - Softmax: Copnverts oputput logits to probabilities, making it suitable for multi-class classficiation
#
#
# Prediction
# - Argmax: Chooses the class with the highest probability

# %%
import torch.nn as nn
import torch.nn.init


class NeuralNetwork(nn.Module):

    def __init__(self,
                 input_size,
                 num_classes,
                 list_hidden,
                 activation='relu'):
       
        super(NeuralNetwork, self).__init__()

        self.input_size = input_size
        self.num_classes = num_classes
        self.list_hidden = list_hidden
        self.activation = activation

    def create_network(self):
       
        layers = []

       
        layers.append(nn.Linear(self.input_size, self.list_hidden[0]))  # input to first hidden layer


      
        layers.append(self.get_activation(self.activation))  # Activation function for first layer

        # Iterate over other hidden layers just before the last layer
        for i in range(len(self.list_hidden) - 1):

           
            layers.append(nn.Linear(self.list_hidden[i], self.list_hidden[i + 1]))  # Between hidden layers

          
            layers.append(self.get_activation(self.activation))  # Activation for each hidden layer

        
        layers.append(nn.Linear(self.list_hidden[-1], self.num_classes))  # Last hidden to output
        layers.append(nn.Softmax(dim=1))  # Softmax for classification
        
        self.layers = nn.Sequential(*layers)

    def init_weights(self):
       
        torch.manual_seed(2)

        # For each layer in the network
        for module in self.modules():

            # If it is a torch.nn.Linear layer
            if isinstance(module, nn.Linear):
               
                nn.init.normal_(module.weight, mean=0, std=0.1)

                nn.init.constant_(module.bias, 0)

                

    def get_activation(self,
                       mode='relu'):
        
        activation = nn.Sigmoid()

        if mode == 'tanh':
            activation = nn.Tanh()

        elif mode == 'relu':
            activation = nn.ReLU(inplace=True)

        return activation

    def forward_manual(self,
                       x,
                       verbose=False):
       

        # For each layer in the network
        for i in range(len(self.layers) - 1):

            # If it is a torch.nn.Linear layer
            if isinstance(self.layers[i], nn.Linear):

                x = torch.matmul(x, self.layers[i].weight.T) + self.layers[i].bias

            # If it is another function
            else:
        
                x = self.layers[i](x)

            if verbose:
                # Print the output of the layer
                print('Output of layer ' + str(i))
                print(x, '\n')

        # Apply the softmax function
        probabilities = self.layers[-1](x)

        if verbose:
            print('Output of layer ' + str(len(self.layers) - 1))
            print(probabilities, '\n')

        return x, probabilities

    def forward(self,
                x,
                verbose=False):
        

        # For each layer in the network
        for i in range(len(self.layers) - 1):

            # Call the forward() function of the layer
            # and return the result to x.
            x = self.layers[i](x)

            if verbose:
                # Print the output of the layer
                print('Output of layer ' + str(i))
                print(x, '\n')

        # Apply the softmax function
        probabilities = self.layers[-1](x)

        if verbose:
            print('Output of layer ' + str(len(self.layers) - 1))
            print(probabilities, '\n')

        return x, probabilities

    def predict(self,
                probabilities):
       
        return torch.argmax(probabilities, dim=1)

# %% [markdown]
# Model Initialization : Initializes the nueral network with the specified parameters

# %%
input_size = 12
number_of_classes = 3
list_hidden = [5, 10]
activation = 'relu'

network = NeuralNetwork(input_size, number_of_classes, list_hidden, activation)

# %%
network.create_network()

# %%
print(network)
# Out:
# NeuralNetwork(
#   (layers): Sequential(
#     (0): Linear(in_features=12, out_features=5, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=5, out_features=10, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=10, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )

# %% [markdown]
# Initializing the model weights

# %%
init_weights = network.init_weights()
print(network.layers[0].weight)
print(network.layers[0].bias)
# Out:
# Parameter containing:
# tensor([[-0.1041,  0.0917, -0.1304, -0.1110, -0.1219,  0.1168, -0.1057, -0.0119,
#          -0.0908,  0.0345, -0.0571, -0.0235],
#         [ 0.1008, -0.0753, -0.0225, -0.0433, -0.1507, -0.0459, -0.0848,  0.0527,
#           0.0030, -0.0050,  0.1065,  0.0886],
#         [ 0.0464, -0.0499,  0.0129,  0.2763,  0.0140,  0.1119,  0.0315,  0.1753,
#          -0.0765,  0.1830, -0.0278, -0.0272],
#         [-0.1294, -0.0024, -0.0235, -0.0709,  0.1157,  0.0430, -0.1187, -0.0747,
#          -0.0902, -0.0015,  0.1386,  0.2579],
#         [ 0.1141, -0.0635, -0.1470, -0.0213,  0.1410, -0.0388,  0.0398, -0.1104,
#           0.2113, -0.0975,  0.0176, -0.0132]], requires_grad=True)
# Parameter containing:
# tensor([0., 0., 0., 0., 0.], requires_grad=True)

# %% [markdown]
# Forward Propagation: compute output of each layer

# %%
x , probabilities = network.forward(X_train, verbose = True)
# Out:
# Output of layer 0
# tensor([[-0.1268,  0.1018,  0.4530, -0.0503,  0.0210],
#         [-0.2470, -0.0958,  0.3842, -0.5461, -0.2657],
#         [-0.5204, -0.4312,  0.5648,  0.3529,  0.7501],
#         ...,
#         [-0.4739, -0.1654, -0.0017, -0.8058, -0.7422],
#         [-0.2252,  0.1751,  0.4557, -0.1918,  0.0161],
#         [ 0.0229, -0.1594,  0.4184, -0.4286,  0.3029]],
#        grad_fn=<AddmmBackward0>)
#
# Output of layer 1
# tensor([[0.0000, 0.1018, 0.4530, 0.0000, 0.0210],
#         [0.0000, 0.0000, 0.3842, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.5648, 0.3529, 0.7501],
#         ...,
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.1751, 0.4557, 0.0000, 0.0161],
#         [0.0229, 0.0000, 0.4184, 0.0000, 0.3029]], grad_fn=<ReluBackward0>)
#
# Output of layer 2
# tensor([[-0.0419,  0.0374,  0.0893,  ...,  0.0109, -0.0408,  0.0154],
#         [-0.0367,  0.0318,  0.0811,  ...,  0.0124, -0.0318,  0.0132],
#         [ 0.0052,  0.0222,  0.1585,  ..., -0.0675, -0.1259,  0.0352],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.0429,  0.0370,  0.0853,  ...,  0.0112, -0.0431,  0.0150],
#         [-0.0147,  0.0425,  0.0896,  ..., -0.0295, -0.0374,  0.0193]],
#        grad_fn=<AddmmBackward0>)
#
# Output of layer 3
# tensor([[0.0000, 0.0374, 0.0893,  ..., 0.0109, 0.0000, 0.0154],
#         [0.0000, 0.0318, 0.0811,  ..., 0.0124, 0.0000, 0.0132],
#         [0.0052, 0.0222, 0.1585,  ..., 0.0000, 0.0000, 0.0352],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0370, 0.0853,  ..., 0.0112, 0.0000, 0.0150],
#         [0.0000, 0.0425, 0.0896,  ..., 0.0000, 0.0000, 0.0193]],
#        grad_fn=<ReluBackward0>)
#
# Output of layer 4
# tensor([[0.0042, 0.0029, 0.0120],
#         [0.0039, 0.0023, 0.0114],
#         [0.0161, 0.0158, 0.0159],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0039, 0.0025, 0.0115],
#         [0.0038, 0.0070, 0.0083]], grad_fn=<AddmmBackward0>)
#
# Output of layer 5
# tensor([[0.3326, 0.3322, 0.3352],
#         [0.3327, 0.3321, 0.3352],
#         [0.3334, 0.3333, 0.3333],
#         ...,
#         [0.3333, 0.3333, 0.3333],
#         [0.3326, 0.3322, 0.3352],
#         [0.3325, 0.3335, 0.3340]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# Loss and Optimizer
# - CrossEntropyLoss: Suitable for Classification tasks with multiple classes
# - Adam Optimizer: Efficient gradient descent with adaptive learning rates

# %%
criterion = nn.CrossEntropyLoss()

# %%
optimizer = optim.Adam(params = network.parameters() , lr = 0.001)

# %% [markdown]
# Training the network

# %%
data_loader = DataLoader (X_train, y_train , 32)

# %%
e = 0
max_epochs = 300
is_converged = False
previous_loss = 0
losses = []

# For each epoch
while e < max_epochs and is_converged is not True:
    
    current_epoch_loss = 0
    
    # TODO: Get the batch for this epoch.
    X_batch, y_batch = data_loader.get_batch()
    
    # For each batch
    for X, y in zip(X_batch, y_batch):
        X = torch.Tensor(X)
        y = torch.Tensor(y).to(torch.long)
        
        # TODO: Empty the gradients of the network.
        optimizer.zero_grad()
        
        # TODO: Forward propagation
        scores, probabilities = network.forward(X)
        
        # TODO: Compute the loss
        loss = criterion (scores, y)
        
        # TODO: Backward propagation
        loss.backward()
        
        # TODO: Update parameters
        optimizer.step()
        
        current_epoch_loss += loss.item()
    
    average_loss = current_epoch_loss / len(X_batch)
    losses.append(average_loss)
    
    # Display the average loss per epoch
    print('Epoch:', e + 1, '\tLoss: {:.6f}'.format(average_loss))
    
    if abs(previous_loss - loss) < 0.00005:
        is_converged = True
    else:
        previous_loss = loss
        e += 1
# Out:
# Epoch: 1 	Loss: 0.259171
# Epoch: 2 	Loss: 0.138176
# Epoch: 3 	Loss: 0.126577
# Epoch: 4 	Loss: 0.109205
# Epoch: 5 	Loss: 0.099865
# Epoch: 6 	Loss: 0.097003
# Epoch: 7 	Loss: 0.095792
# Epoch: 8 	Loss: 0.095183
# Epoch: 9 	Loss: 0.094492
# Epoch: 10 	Loss: 0.094364
# Epoch: 11 	Loss: 0.094081
# Epoch: 12 	Loss: 0.093474
# Epoch: 13 	Loss: 0.092960
# Epoch: 14 	Loss: 0.092753
# Epoch: 15 	Loss: 0.092658
# Epoch: 16 	Loss: 0.092517
# Epoch: 17 	Loss: 0.092514
# Epoch: 18 	Loss: 0.092391
# Epoch: 19 	Loss: 0.092468
# Epoch: 20 	Loss: 0.092224
# Epoch: 21 	Loss: 0.092306
# Epoch: 22 	Loss: 0.092204
# Epoch: 23 	Loss: 0.092116
# Epoch: 24 	Loss: 0.092108
# Epoch: 25 	Loss: 0.091901
# Epoch: 26 	Loss: 0.091390
# Epoch: 27 	Loss: 0.091137
# Epoch: 28 	Loss: 0.090942
# Epoch: 29 	Loss: 0.090949
# Epoch: 30 	Loss: 0.090942
# Epoch: 31 	Loss: 0.090847
# Epoch: 32 	Loss: 0.090546
# Epoch: 33 	Loss: 0.090467
# Epoch: 34 	Loss: 0.090645
# Epoch: 35 	Loss: 0.090716
# Epoch: 36 	Loss: 0.090396
# Epoch: 37 	Loss: 0.090612
# Epoch: 38 	Loss: 0.090563
# Epoch: 39 	Loss: 0.090515
# Epoch: 40 	Loss: 0.090595
# Epoch: 41 	Loss: 0.090551
# Epoch: 42 	Loss: 0.090408
# Epoch: 43 	Loss: 0.090468
# Epoch: 44 	Loss: 0.090479
# Epoch: 45 	Loss: 0.090473
# Epoch: 46 	Loss: 0.090297
# Epoch: 47 	Loss: 0.090189
# Epoch: 48 	Loss: 0.089950
# Epoch: 49 	Loss: 0.089652
# Epoch: 50 	Loss: 0.089782
# Epoch: 51 	Loss: 0.089489
# Epoch: 52 	Loss: 0.089466
# Epoch: 53 	Loss: 0.089549
# Epoch: 54 	Loss: 0.089605
# Epoch: 55 	Loss: 0.089418
# Epoch: 56 	Loss: 0.089416
# Epoch: 57 	Loss: 0.089603
# Epoch: 58 	Loss: 0.089431
# Epoch: 59 	Loss: 0.089534
# Epoch: 60 	Loss: 0.089434
# Epoch: 61 	Loss: 0.089558
# Epoch: 62 	Loss: 0.089539
# Epoch: 63 	Loss: 0.089451
# Epoch: 64 	Loss: 0.089257
# Epoch: 65 	Loss: 0.089425
# Epoch: 66 	Loss: 0.089462
# Epoch: 67 	Loss: 0.089415
# Epoch: 68 	Loss: 0.089565
# Epoch: 69 	Loss: 0.089453
# Epoch: 70 	Loss: 0.089358
# Epoch: 71 	Loss: 0.089431
# Epoch: 72 	Loss: 0.089377
# Epoch: 73 	Loss: 0.089426
# Epoch: 74 	Loss: 0.089297
# Epoch: 75 	Loss: 0.089369
# Epoch: 76 	Loss: 0.089379
# Epoch: 77 	Loss: 0.089400
# Epoch: 78 	Loss: 0.089188
# Epoch: 79 	Loss: 0.089330
# Epoch: 80 	Loss: 0.089551
# Epoch: 81 	Loss: 0.089213
# Epoch: 82 	Loss: 0.089374
# Epoch: 83 	Loss: 0.089537
# Epoch: 84 	Loss: 0.089188
# Epoch: 85 	Loss: 0.089503
# Epoch: 86 	Loss: 0.089219
# Epoch: 87 	Loss: 0.089395
# Epoch: 88 	Loss: 0.089363
# Epoch: 89 	Loss: 0.089260
# Epoch: 90 	Loss: 0.089227
# Epoch: 91 	Loss: 0.089402
# Epoch: 92 	Loss: 0.089348
# Epoch: 93 	Loss: 0.089417
# Epoch: 94 	Loss: 0.089504
# Epoch: 95 	Loss: 0.089361
# Epoch: 96 	Loss: 0.089316
# Epoch: 97 	Loss: 0.089367
# Epoch: 98 	Loss: 0.089382
# Epoch: 99 	Loss: 0.089265
# Epoch: 100 	Loss: 0.089273
# Epoch: 101 	Loss: 0.089221
# Epoch: 102 	Loss: 0.089270
# Epoch: 103 	Loss: 0.089406
# Epoch: 104 	Loss: 0.089177
# Epoch: 105 	Loss: 0.089456
# Epoch: 106 	Loss: 0.089234
# Epoch: 107 	Loss: 0.089160
# Epoch: 108 	Loss: 0.089372
# Epoch: 109 	Loss: 0.089166
# Epoch: 110 	Loss: 0.089419
# Epoch: 111 	Loss: 0.089214
# Epoch: 112 	Loss: 0.089260
# Epoch: 113 	Loss: 0.089173
# Epoch: 114 	Loss: 0.089175
# Epoch: 115 	Loss: 0.089389
# Epoch: 116 	Loss: 0.089189
# Epoch: 117 	Loss: 0.089248
# Epoch: 118 	Loss: 0.089229
# Epoch: 119 	Loss: 0.089298
# Epoch: 120 	Loss: 0.089094
# Epoch: 121 	Loss: 0.089155
# Epoch: 122 	Loss: 0.089237
# Epoch: 123 	Loss: 0.089313
# Epoch: 124 	Loss: 0.089139
# Epoch: 125 	Loss: 0.089106
# Epoch: 126 	Loss: 0.089148
# Epoch: 127 	Loss: 0.089264
# Epoch: 128 	Loss: 0.089284
# Epoch: 129 	Loss: 0.089295
# Epoch: 130 	Loss: 0.089295
# Epoch: 131 	Loss: 0.089127
# Epoch: 132 	Loss: 0.089125
# Epoch: 133 	Loss: 0.089294
# Epoch: 134 	Loss: 0.089133
# Epoch: 135 	Loss: 0.089103
# Epoch: 136 	Loss: 0.089245
# Epoch: 137 	Loss: 0.089289
# Epoch: 138 	Loss: 0.089114
# Epoch: 139 	Loss: 0.089230
# Epoch: 140 	Loss: 0.089230
# Epoch: 141 	Loss: 0.089224
# Epoch: 142 	Loss: 0.089020
# Epoch: 143 	Loss: 0.089231
# Epoch: 144 	Loss: 0.089287
# Epoch: 145 	Loss: 0.089173
# Epoch: 146 	Loss: 0.089148
# Epoch: 147 	Loss: 0.089244
# Epoch: 148 	Loss: 0.089017
# Epoch: 149 	Loss: 0.089318
# Epoch: 150 	Loss: 0.089091
# Epoch: 151 	Loss: 0.089205
# Epoch: 152 	Loss: 0.089170
# Epoch: 153 	Loss: 0.089102
# Epoch: 154 	Loss: 0.089392
# Epoch: 155 	Loss: 0.089103
# Epoch: 156 	Loss: 0.089135
# Epoch: 157 	Loss: 0.089173
# Epoch: 158 	Loss: 0.089190
# Epoch: 159 	Loss: 0.089057
# Epoch: 160 	Loss: 0.089228
# Epoch: 161 	Loss: 0.089128
# Epoch: 162 	Loss: 0.089128
# Epoch: 163 	Loss: 0.089218
# Epoch: 164 	Loss: 0.089135
# Epoch: 165 	Loss: 0.089247
# Epoch: 166 	Loss: 0.089314
# Epoch: 167 	Loss: 0.089118
# Epoch: 168 	Loss: 0.089262
# Epoch: 169 	Loss: 0.089086
# Epoch: 170 	Loss: 0.089133
# Epoch: 171 	Loss: 0.089106
# Epoch: 172 	Loss: 0.089211
# Epoch: 173 	Loss: 0.089283
# Epoch: 174 	Loss: 0.089088
# Epoch: 175 	Loss: 0.089121
# Epoch: 176 	Loss: 0.089141
# Epoch: 177 	Loss: 0.088989
# Epoch: 178 	Loss: 0.089138
# Epoch: 179 	Loss: 0.089171
# Epoch: 180 	Loss: 0.089179
# Epoch: 181 	Loss: 0.089132
# Epoch: 182 	Loss: 0.089058
# Epoch: 183 	Loss: 0.089155
# Epoch: 184 	Loss: 0.089193
# Epoch: 185 	Loss: 0.089074
# Epoch: 186 	Loss: 0.089035
# Epoch: 187 	Loss: 0.089118
# Epoch: 188 	Loss: 0.088824
# Epoch: 189 	Loss: 0.089081
# Epoch: 190 	Loss: 0.089273
# Epoch: 191 	Loss: 0.089078
# Epoch: 192 	Loss: 0.089147
# Epoch: 193 	Loss: 0.089179
# Epoch: 194 	Loss: 0.089140
# Epoch: 195 	Loss: 0.089108
# Epoch: 196 	Loss: 0.089213
# Epoch: 197 	Loss: 0.089018
# Epoch: 198 	Loss: 0.089127
# Epoch: 199 	Loss: 0.089110
# Epoch: 200 	Loss: 0.089092
# Epoch: 201 	Loss: 0.088972
# Epoch: 202 	Loss: 0.089022
# Epoch: 203 	Loss: 0.089105
# Epoch: 204 	Loss: 0.089118
# Epoch: 205 	Loss: 0.089156
# Epoch: 206 	Loss: 0.089147
# Epoch: 207 	Loss: 0.089072
# Epoch: 208 	Loss: 0.089037
# Epoch: 209 	Loss: 0.089194
# Epoch: 210 	Loss: 0.089056
# Epoch: 211 	Loss: 0.088967
# Epoch: 212 	Loss: 0.089149
# Epoch: 213 	Loss: 0.089031
# Epoch: 214 	Loss: 0.088928
# Epoch: 215 	Loss: 0.089073
# Epoch: 216 	Loss: 0.089089
# Epoch: 217 	Loss: 0.089201
# Epoch: 218 	Loss: 0.089095
# Epoch: 219 	Loss: 0.089227
# Epoch: 220 	Loss: 0.089061
# Epoch: 221 	Loss: 0.089076
# Epoch: 222 	Loss: 0.089234
# Epoch: 223 	Loss: 0.089173
# Epoch: 224 	Loss: 0.089066
# Epoch: 225 	Loss: 0.089130
# Epoch: 226 	Loss: 0.089144
# Epoch: 227 	Loss: 0.089099
# Epoch: 228 	Loss: 0.089138
# Epoch: 229 	Loss: 0.089127
# Epoch: 230 	Loss: 0.089005
# Epoch: 231 	Loss: 0.089044
# Epoch: 232 	Loss: 0.089068
# Epoch: 233 	Loss: 0.089153
# Epoch: 234 	Loss: 0.088926
# Epoch: 235 	Loss: 0.089258
# Epoch: 236 	Loss: 0.089012
# Epoch: 237 	Loss: 0.089099
# Epoch: 238 	Loss: 0.089089
# Epoch: 239 	Loss: 0.089160
# Epoch: 240 	Loss: 0.089152
# Epoch: 241 	Loss: 0.089049
# Epoch: 242 	Loss: 0.089010
# Epoch: 243 	Loss: 0.089052
# Epoch: 244 	Loss: 0.088981
# Epoch: 245 	Loss: 0.089098
# Epoch: 246 	Loss: 0.088976
# Epoch: 247 	Loss: 0.089036
# Epoch: 248 	Loss: 0.088995
# Epoch: 249 	Loss: 0.089161
# Epoch: 250 	Loss: 0.089094
# Epoch: 251 	Loss: 0.089173
# Epoch: 252 	Loss: 0.089223
# Epoch: 253 	Loss: 0.089151
# Epoch: 254 	Loss: 0.089007
# Epoch: 255 	Loss: 0.089046
# Epoch: 256 	Loss: 0.088935
# Epoch: 257 	Loss: 0.089039
# Epoch: 258 	Loss: 0.089108
# Epoch: 259 	Loss: 0.089133
# Epoch: 260 	Loss: 0.089150
# Epoch: 261 	Loss: 0.088967
# Epoch: 262 	Loss: 0.089064
# Epoch: 263 	Loss: 0.089021
# Epoch: 264 	Loss: 0.089059
# Epoch: 265 	Loss: 0.089030
# Epoch: 266 	Loss: 0.089033
# Epoch: 267 	Loss: 0.089082
# Epoch: 268 	Loss: 0.089129
# Epoch: 269 	Loss: 0.089184
# Epoch: 270 	Loss: 0.089143
# Epoch: 271 	Loss: 0.089036
# Epoch: 272 	Loss: 0.089069
# Epoch: 273 	Loss: 0.089028
# Epoch: 274 	Loss: 0.089113
# Epoch: 275 	Loss: 0.089024
# Epoch: 276 	Loss: 0.089141
# Epoch: 277 	Loss: 0.089051
# Epoch: 278 	Loss: 0.088863
# Epoch: 279 	Loss: 0.089093
# Epoch: 280 	Loss: 0.089171
# Epoch: 281 	Loss: 0.089007
# Epoch: 282 	Loss: 0.089156
# Epoch: 283 	Loss: 0.089010
# Epoch: 284 	Loss: 0.088971
# Epoch: 285 	Loss: 0.089051
# Epoch: 286 	Loss: 0.089136
# Epoch: 287 	Loss: 0.088953
# Epoch: 288 	Loss: 0.089065
# Epoch: 289 	Loss: 0.089204
# Epoch: 290 	Loss: 0.088973
# Epoch: 291 	Loss: 0.088967
# Epoch: 292 	Loss: 0.089075
# Epoch: 293 	Loss: 0.088943
# Epoch: 294 	Loss: 0.089087
# Epoch: 295 	Loss: 0.089072
# Epoch: 296 	Loss: 0.089010
# Epoch: 297 	Loss: 0.088891
# Epoch: 298 	Loss: 0.089097
# Epoch: 299 	Loss: 0.088967
# Epoch: 300 	Loss: 0.089037

# %% [markdown]
# Do testing on test data

# %%
network.eval()
# Out:
# NeuralNetwork(
#   (layers): Sequential(
#     (0): Linear(in_features=12, out_features=5, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=5, out_features=10, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=10, out_features=3, bias=True)
#     (5): Softmax(dim=1)
#   )
# )

# %%
scores, probabilities = network.forward(X_test)
predictions = network.predict(probabilities)
print(predictions)
# Out:
# tensor([0, 1, 0,  ..., 1, 0, 0])

# %% [markdown]
# # Section 7: Validation and Error Analysis

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


num_correct = (predictions == y_test).sum().item()
print("Number of correct instances: ", num_correct)
accuracy = num_correct / len(y_test)
print('Acccuracy: {:.4f}'.format(accuracy))

y_test_np = y_test.numpy()
y_pred_np = predictions.numpy()

print("Classification Report:")
print(classification_report(y_test_np, y_pred_np))
# Out:
# Number of correct instances:  26463
# Acccuracy: 0.9563
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20526
#            1       0.86      0.95      0.90      5894
#            2       0.54      0.27      0.36      1253
#
#     accuracy                           0.96     27673
#    macro avg       0.80      0.74      0.75     27673
# weighted avg       0.95      0.96      0.95     27673

# %% [markdown]
# Based on the classification report, for Class 0 (Employed)
#
# - Precision = 1.00 - Every prediction for "Employed" was correct (no false positives).
# - Recall = 1.00 - Every actual "Employed" individual was correctly identified (no false negatives).
# - F1-score = 1.00 - Perfect classification for this class.
#
#
# As for Class 1 (Not in the Labor Force)
#
# - Precision = 0.85 - 85% of the predicted "Not in Labor Force" cases were correct. Some false positives exist.
# - Recall = 0.97 - 97% of actual "Not in Labor Force" individuals were correctly identified
# - F1-score = 0.91 - Good balance between precision and recall.
#
#
# While for Class 2 (Unemployed)
#
# - Precision = 0.60 - Only 60% of the predicted "Unemployed" cases were correct (high false positives).
# - Recall = 0.21 - Only 21% of actual "Unemployed" people were correctly identified (high false negatives).
# - F1-score = 0.31 - Poor balance between precision and recall.
#
#
# From this classification report, we can conclude that the model struggles the most with Class 2 (Unemployed), as it frequently misclassifies individuals in this category as either "Not in the Labor Force" or "Employed." This indicates that the model has difficulty distinguishing unemployed individuals, likely due to class imbalance features between categories.

# %%
conf_matrix = confusion_matrix(y_test.numpy(), predictions.numpy())

# Print Confusion Matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[20523     2     1]
#  [    1  5604   289]
#  [    0   917   336]]

# %% [markdown]
# - Class 0 (Employed) is classified almost perfectly with only 1 mistake (classified as Not in Labor Force).
#
# - Class 1 (Not in Labor Force) is mostly well-classified, but 171 individuals were mistakenly labeled as Unemployed.
#
# - Class 2 (Unemployed) is the most misclassified:
#
#     - 993 unemployed individuals were predicted as "Not in Labor Force" (likely because the model struggles to distinguish between these two groups).
#
#     - Only 260 unemployed cases were correctly classified, which aligns with the low recall (0.21) for Class 2 in the classification report.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Employed","Not in Labor Force", "Unemployed"],
            yticklabels=["Employed", "Not in Labor Force", "Unemployed"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix Heatmap")
plt.show()
